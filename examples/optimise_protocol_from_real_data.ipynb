# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)


from ED_MRI.optimise import optimise_experiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 8
#       4 if module_path not in sys.path:
#       5     sys.path.append(module_path)
# ----> 8 from ED_MRI.optimise import optimise_experiment
#
# ModuleNotFoundError: No module named 'ED_MRI'

# %%
base_dir = "/Users/scmps8/Data/wand/WAND/sub-01187/ses-02/dwi"

result = optimise_experiment(
    input_data=f"{base_dir}/sub-01187_ses-02_acq-CHARMED_dir-AP_part-mag_dwi.nii.gz",
    target_data=f"{base_dir}/tensor/dt.nii.gz",
    superdesign=f"{base_dir}/sub-01187_ses-02_acq-CHARMED_dir-AP_part-mag_dwi.grad",
    opt_protocol_size=0.5,
    output_dir=f"{base_dir}/edmri_output",
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ..optimise import optimise_experiment
#       3 base_dir = "/Users/scmps8/Data/wand/WAND/sub-01187/ses-02/dwi"
#       5 result = optimise_experiment(
#       6     input_data=f"{base_dir}/sub-01187_ses-02_acq-CHARMED_dir-AP_part-mag_dwi.nii.gz",
#       7     target_data=f"{base_dir}/tensor/dt.nii.gz",
#    (...)
#      10     output_dir=f"{base_dir}/edmri_output",
#      11 )
#
# ImportError: attempted relative import with no known parent package
